# %% [markdown]
# # Intelligent Resume Matcher - Model Training
#
# This notebook demonstrates how to train the classification model using a dataset of Resumes.
#
# ## 1. Setup & Installation

# %%
# !pip install sentence-transformers nltk pandas scikit-learn numpy joblib

# %% [markdown]
# ## 2. Load Dataset
# You can load a dataset directly from Kaggle or upload your own CSV.

# %%
import os
import pandas as pd

# EXAMPLE: Load a dataset (upload 'Resume.csv' to the input directory in Kaggle)
# df = pd.read_csv('/kaggle/input/resume-dataset/Resume.csv')
# df.head()

# %% [markdown]
# ## 3. Clone / Import Project Logic
# In a real Kaggle kernel, you would either copy the script logic here or clone the repository.

# %%
# For demonstration, we will define the simplified logic directly here so this notebook is self-contained.
# In production, you'd clone the repo: !git clone https://github.com/your/repo.git

import numpy as np

def clean_text(text):
    # Placeholder for full cleaner logic
    return str(text).lower()

# ... (Include core feature extraction logic if needed or import from Repo)

# %% [markdown]
# ## 4. Train Model
# Run the training pipeline.

# %%
# !python src/training/train_model.py --csv /path/to/resume.csv
